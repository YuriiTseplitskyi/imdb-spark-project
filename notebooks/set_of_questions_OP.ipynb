# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import col, avg
from pyspark.sql.window import Window
from schemas import data_frames

# %% [markdown]
# # **Question 1**
#
# > Select top 5 genres that degraded in ratings during 2019-2024

# %%
# Filter last 5 years and only valid ratings and genres, group results by startYear and genre
recent = (
    data_frames["title_basics"]
    .filter(col("startYear").isin([2019, 2024]))
    .join(data_frames["title_ratings"], "tconst")
    .filter(
        (col("averageRating").isNotNull()) &
        (col("genres").isNotNull()) &
        (col("numVotes") >= 1000) &
        (col("startYear").cast("int") <= 2025)
        )
    .groupBy("startYear", "genres")
    .agg(avg("averageRating").alias("avgRating"))
  )

# Compare 2019 vs. 2024
genres = (
    recent.groupBy("genres")
    .pivot("startYear", [2019, 2024])
    .agg(avg("avgRating"))
    .withColumnRenamed("2019", "rating_2019")
    .withColumnRenamed("2024", "rating_2024")
    .dropna(subset=["rating_2019", "rating_2024"])
  )

degraded_genres = (
    genres.withColumn("rating_diff", col("rating_2024") - col("rating_2019"))
    .orderBy(col("rating_diff").asc())
    .limit(5)
  )

upgraded_genres = (
    genres.withColumn("rating_diff", col("rating_2024") - col("rating_2019"))
    .orderBy(col("rating_diff").desc())
    .limit(5)
)

degraded_genres_pd = degraded_genres.select("genres", "rating_2019", "rating_2024", "rating_diff").toPandas()
degraded_genres_pd.style \
    .format({
        "rating_diff": "{:.2f}",
        "rating_2019": "{:.2f}",
        "rating_2024": "{:.2f}"
    }) \
    .set_properties(**{'background-color': '#f9f9f9', 'color': 'black'})
# Out:
# <style type="text/css">
# #T_c17d1_row0_col0, #T_c17d1_row0_col1, #T_c17d1_row0_col2, #T_c17d1_row0_col3, #T_c17d1_row1_col0, #T_c17d1_row1_col1, #T_c17d1_row1_col2, #T_c17d1_row1_col3, #T_c17d1_row2_col0, #T_c17d1_row2_col1, #T_c17d1_row2_col2, #T_c17d1_row2_col3, #T_c17d1_row3_col0, #T_c17d1_row3_col1, #T_c17d1_row3_col2, #T_c17d1_row3_col3, #T_c17d1_row4_col0, #T_c17d1_row4_col1, #T_c17d1_row4_col2, #T_c17d1_row4_col3 {
#   background-color: #f9f9f9;
#   color: black;
# }
# </style>
# <table id="T_c17d1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c17d1_level0_col0" class="col_heading level0 col0" >genres</th>
#       <th id="T_c17d1_level0_col1" class="col_heading level0 col1" >rating_2019</th>
#       <th id="T_c17d1_level0_col2" class="col_heading level0 col2" >rating_2024</th>
#       <th id="T_c17d1_level0_col3" class="col_heading level0 col3" >rating_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c17d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c17d1_row0_col0" class="data row0 col0" >Documentary,War</td>
#       <td id="T_c17d1_row0_col1" class="data row0 col1" >7.50</td>
#       <td id="T_c17d1_row0_col2" class="data row0 col2" >1.90</td>
#       <td id="T_c17d1_row0_col3" class="data row0 col3" >-5.60</td>
#     </tr>
#     <tr>
#       <th id="T_c17d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c17d1_row1_col0" class="data row1 col0" >Drama,Fantasy,Mystery</td>
#       <td id="T_c17d1_row1_col1" class="data row1 col1" >7.62</td>
#       <td id="T_c17d1_row1_col2" class="data row1 col2" >4.75</td>
#       <td id="T_c17d1_row1_col3" class="data row1 col3" >-2.87</td>
#     </tr>
#     <tr>
#       <th id="T_c17d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c17d1_row2_col0" class="data row2 col0" >Adventure,Biography,Drama</td>
#       <td id="T_c17d1_row2_col1" class="data row2 col1" >6.57</td>
#       <td id="T_c17d1_row2_col2" class="data row2 col2" >3.80</td>
#       <td id="T_c17d1_row2_col3" class="data row2 col3" >-2.77</td>
#     </tr>
#     <tr>
#       <th id="T_c17d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c17d1_row3_col0" class="data row3 col0" >Animation,Comedy</td>
#       <td id="T_c17d1_row3_col1" class="data row3 col1" >6.75</td>
#       <td id="T_c17d1_row3_col2" class="data row3 col2" >4.36</td>
#       <td id="T_c17d1_row3_col3" class="data row3 col3" >-2.39</td>
#     </tr>
#     <tr>
#       <th id="T_c17d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c17d1_row4_col0" class="data row4 col0" >Comedy,Fantasy</td>
#       <td id="T_c17d1_row4_col1" class="data row4 col1" >6.85</td>
#       <td id="T_c17d1_row4_col2" class="data row4 col2" >4.57</td>
#       <td id="T_c17d1_row4_col3" class="data row4 col3" >-2.28</td>
#     </tr>
#   </tbody>
# </table>

# %%
upgraded_genres_pd = upgraded_genres.select("genres", "rating_2019", "rating_2024", "rating_diff").limit(20).toPandas()
upgraded_genres_pd.style \
    .format({
        "rating_diff": "{:.2f}",
        "rating_2019": "{:.2f}",
        "rating_2024": "{:.2f}"
    }) \
    .set_properties(**{'background-color': '#f9f9f9', 'color': 'black'})
# Out:
# <style type="text/css">
# #T_ba724_row0_col0, #T_ba724_row0_col1, #T_ba724_row0_col2, #T_ba724_row0_col3, #T_ba724_row1_col0, #T_ba724_row1_col1, #T_ba724_row1_col2, #T_ba724_row1_col3, #T_ba724_row2_col0, #T_ba724_row2_col1, #T_ba724_row2_col2, #T_ba724_row2_col3, #T_ba724_row3_col0, #T_ba724_row3_col1, #T_ba724_row3_col2, #T_ba724_row3_col3, #T_ba724_row4_col0, #T_ba724_row4_col1, #T_ba724_row4_col2, #T_ba724_row4_col3 {
#   background-color: #f9f9f9;
#   color: black;
# }
# </style>
# <table id="T_ba724" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba724_level0_col0" class="col_heading level0 col0" >genres</th>
#       <th id="T_ba724_level0_col1" class="col_heading level0 col1" >rating_2019</th>
#       <th id="T_ba724_level0_col2" class="col_heading level0 col2" >rating_2024</th>
#       <th id="T_ba724_level0_col3" class="col_heading level0 col3" >rating_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba724_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ba724_row0_col0" class="data row0 col0" >Comedy,Talk-Show</td>
#       <td id="T_ba724_row0_col1" class="data row0 col1" >1.50</td>
#       <td id="T_ba724_row0_col2" class="data row0 col2" >7.20</td>
#       <td id="T_ba724_row0_col3" class="data row0 col3" >5.70</td>
#     </tr>
#     <tr>
#       <th id="T_ba724_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ba724_row1_col0" class="data row1 col0" >Music</td>
#       <td id="T_ba724_row1_col1" class="data row1 col1" >3.70</td>
#       <td id="T_ba724_row1_col2" class="data row1 col2" >7.87</td>
#       <td id="T_ba724_row1_col3" class="data row1 col3" >4.17</td>
#     </tr>
#     <tr>
#       <th id="T_ba724_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ba724_row2_col0" class="data row2 col0" >Crime,Horror,Thriller</td>
#       <td id="T_ba724_row2_col1" class="data row2 col1" >3.50</td>
#       <td id="T_ba724_row2_col2" class="data row2 col2" >7.30</td>
#       <td id="T_ba724_row2_col3" class="data row2 col3" >3.80</td>
#     </tr>
#     <tr>
#       <th id="T_ba724_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ba724_row3_col0" class="data row3 col0" >Fantasy</td>
#       <td id="T_ba724_row3_col1" class="data row3 col1" >4.10</td>
#       <td id="T_ba724_row3_col2" class="data row3 col2" >6.90</td>
#       <td id="T_ba724_row3_col3" class="data row3 col3" >2.80</td>
#     </tr>
#     <tr>
#       <th id="T_ba724_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ba724_row4_col0" class="data row4 col0" >Drama,Family,Fantasy</td>
#       <td id="T_ba724_row4_col1" class="data row4 col1" >6.30</td>
#       <td id="T_ba724_row4_col2" class="data row4 col2" >9.00</td>
#       <td id="T_ba724_row4_col3" class="data row4 col3" >2.70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Question 2**
# > Analyze the career trajectory of directors by comparing their average movie ratings in their early career (first 5 films)
# versus their established period (films after the first 5), for directors with at least 10 films and 15+ years of activity.

# %%
director_films = (
    data_frames["title_crew"]
    .join(data_frames["title_ratings"], "tconst")
    .join(data_frames["title_basics"], "tconst")
    .filter(
        col("directors").isNotNull() &
        col("startYear").isNotNull() &
        (col("startYear") > 0) &
        (col("numVotes") >= 1000)
    )
)

director_activity = (
    director_films
    .groupBy("directors")
    .agg(
        F.count("tconst").alias("num_movies"),
        F.max("startYear").alias("max_year"),
        F.min("startYear").alias("min_year")
    )
    .filter(
        (col("num_movies") >= 10) &
        (col("max_year") - col("min_year") >= 15)
    )
)

director_films_filtered = (
    director_films
    .join(director_activity, "directors")
    .filter(
        (col("num_movies") >= 10) &
        (col("max_year") - col("min_year") >= 15)
    )
)

windowSpec = Window.partitionBy("directors").orderBy("startYear")

director_films_with_order = director_films_filtered \
    .withColumn("film_order", F.row_number().over(windowSpec))

early_career = director_films_with_order.filter(col("film_order") <= 5)

windowSpec_total = Window.partitionBy("directors")
total_films = director_films_with_order.withColumn("total_films", F.count("film_order").over(windowSpec_total))
established_period = total_films.filter(col("film_order") > col("total_films") - 5)

# Count average ratings for each period of time
early_career_avg = early_career.groupBy("directors").agg(F.avg("averageRating").alias("early_career_avg"))
established_period_avg = established_period.groupBy("directors").agg(F.avg("averageRating").alias("established_period_avg"))

career_trajectory = (
    early_career_avg
    .join(established_period_avg, "directors")
    .orderBy(F.col("early_career_avg").desc())
)

directors_with_names = data_frames["name_basics"].select("nconst", "primaryName")

career_trajectory_with_names = (
    career_trajectory
    .join(directors_with_names, career_trajectory["directors"] == directors_with_names["nconst"], "left")
    .select(
        directors_with_names["primaryName"].alias("director_name"),
        career_trajectory["early_career_avg"],
        career_trajectory["established_period_avg"]
    )
    .orderBy(F.col("early_career_avg").desc())
)

total_records = career_trajectory_with_names.count()
print(f"Загальна кількість записів у відповіді: {total_records}")

career_trajectory_with_names_pd = career_trajectory_with_names.select("director_name", "early_career_avg", "established_period_avg").limit(20).toPandas()
career_trajectory_with_names_pd.style \
    .format({
        "early_career_avg": "{:.2f}",
        "established_period_avg": "{:.2f}",
    }) \
    .set_properties(**{'background-color': '#f9f9f9', 'color': 'black'})
# Out:
# Загальна кількість записів у відповіді: 1259
# <style type="text/css">
# #T_b1e7e_row0_col0, #T_b1e7e_row0_col1, #T_b1e7e_row0_col2, #T_b1e7e_row1_col0, #T_b1e7e_row1_col1, #T_b1e7e_row1_col2, #T_b1e7e_row2_col0, #T_b1e7e_row2_col1, #T_b1e7e_row2_col2, #T_b1e7e_row3_col0, #T_b1e7e_row3_col1, #T_b1e7e_row3_col2, #T_b1e7e_row4_col0, #T_b1e7e_row4_col1, #T_b1e7e_row4_col2, #T_b1e7e_row5_col0, #T_b1e7e_row5_col1, #T_b1e7e_row5_col2, #T_b1e7e_row6_col0, #T_b1e7e_row6_col1, #T_b1e7e_row6_col2, #T_b1e7e_row7_col0, #T_b1e7e_row7_col1, #T_b1e7e_row7_col2, #T_b1e7e_row8_col0, #T_b1e7e_row8_col1, #T_b1e7e_row8_col2, #T_b1e7e_row9_col0, #T_b1e7e_row9_col1, #T_b1e7e_row9_col2, #T_b1e7e_row10_col0, #T_b1e7e_row10_col1, #T_b1e7e_row10_col2, #T_b1e7e_row11_col0, #T_b1e7e_row11_col1, #T_b1e7e_row11_col2, #T_b1e7e_row12_col0, #T_b1e7e_row12_col1, #T_b1e7e_row12_col2, #T_b1e7e_row13_col0, #T_b1e7e_row13_col1, #T_b1e7e_row13_col2, #T_b1e7e_row14_col0, #T_b1e7e_row14_col1, #T_b1e7e_row14_col2, #T_b1e7e_row15_col0, #T_b1e7e_row15_col1, #T_b1e7e_row15_col2, #T_b1e7e_row16_col0, #T_b1e7e_row16_col1, #T_b1e7e_row16_col2, #T_b1e7e_row17_col0, #T_b1e7e_row17_col1, #T_b1e7e_row17_col2, #T_b1e7e_row18_col0, #T_b1e7e_row18_col1, #T_b1e7e_row18_col2, #T_b1e7e_row19_col0, #T_b1e7e_row19_col1, #T_b1e7e_row19_col2 {
#   background-color: #f9f9f9;
#   color: black;
# }
# </style>
# <table id="T_b1e7e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1e7e_level0_col0" class="col_heading level0 col0" >director_name</th>
#       <th id="T_b1e7e_level0_col1" class="col_heading level0 col1" >early_career_avg</th>
#       <th id="T_b1e7e_level0_col2" class="col_heading level0 col2" >established_period_avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1e7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1e7e_row0_col0" class="data row0 col0" >Alan Ball</td>
#       <td id="T_b1e7e_row0_col1" class="data row0 col1" >8.98</td>
#       <td id="T_b1e7e_row0_col2" class="data row0 col2" >8.08</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1e7e_row1_col0" class="data row1 col0" >Vince Gilligan</td>
#       <td id="T_b1e7e_row1_col1" class="data row1 col1" >8.90</td>
#       <td id="T_b1e7e_row1_col2" class="data row1 col2" >9.42</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1e7e_row2_col0" class="data row2 col0" >Jennifer Getzinger</td>
#       <td id="T_b1e7e_row2_col1" class="data row2 col1" >8.80</td>
#       <td id="T_b1e7e_row2_col2" class="data row2 col2" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1e7e_row3_col0" class="data row3 col0" >Ethan Spaulding</td>
#       <td id="T_b1e7e_row3_col1" class="data row3 col1" >8.74</td>
#       <td id="T_b1e7e_row3_col2" class="data row3 col2" >6.42</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1e7e_row4_col0" class="data row4 col0" >James Roday Rodriguez</td>
#       <td id="T_b1e7e_row4_col1" class="data row4 col1" >8.74</td>
#       <td id="T_b1e7e_row4_col2" class="data row4 col2" >6.64</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1e7e_row5_col0" class="data row5 col0" >Katsumi Tokoro</td>
#       <td id="T_b1e7e_row5_col1" class="data row5 col1" >8.72</td>
#       <td id="T_b1e7e_row5_col2" class="data row5 col2" >8.16</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1e7e_row6_col0" class="data row6 col0" >Alex Graves</td>
#       <td id="T_b1e7e_row6_col1" class="data row6 col1" >8.70</td>
#       <td id="T_b1e7e_row6_col2" class="data row6 col2" >8.36</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1e7e_row7_col0" class="data row7 col0" >R.W. Goodwin</td>
#       <td id="T_b1e7e_row7_col1" class="data row7 col1" >8.68</td>
#       <td id="T_b1e7e_row7_col2" class="data row7 col2" >8.04</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1e7e_row8_col0" class="data row8 col0" >Hideo Kojima</td>
#       <td id="T_b1e7e_row8_col1" class="data row8 col1" >8.68</td>
#       <td id="T_b1e7e_row8_col2" class="data row8 col2" >8.58</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1e7e_row9_col0" class="data row9 col0" >Mehran Modiri</td>
#       <td id="T_b1e7e_row9_col1" class="data row9 col1" >8.64</td>
#       <td id="T_b1e7e_row9_col2" class="data row9 col2" >8.20</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b1e7e_row10_col0" class="data row10 col0" >Colin Bucksey</td>
#       <td id="T_b1e7e_row10_col1" class="data row10 col1" >8.62</td>
#       <td id="T_b1e7e_row10_col2" class="data row10 col2" >7.94</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b1e7e_row11_col0" class="data row11 col0" >Laura Innes</td>
#       <td id="T_b1e7e_row11_col1" class="data row11 col1" >8.60</td>
#       <td id="T_b1e7e_row11_col2" class="data row11 col2" >8.18</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b1e7e_row12_col0" class="data row12 col0" >Amy Sherman-Palladino</td>
#       <td id="T_b1e7e_row12_col1" class="data row12 col1" >8.58</td>
#       <td id="T_b1e7e_row12_col2" class="data row12 col2" >8.24</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b1e7e_row13_col0" class="data row13 col0" >Cary Joji Fukunaga</td>
#       <td id="T_b1e7e_row13_col1" class="data row13 col1" >8.54</td>
#       <td id="T_b1e7e_row13_col2" class="data row13 col2" >7.86</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b1e7e_row14_col0" class="data row14 col0" >Terry McDonough</td>
#       <td id="T_b1e7e_row14_col1" class="data row14 col1" >8.54</td>
#       <td id="T_b1e7e_row14_col2" class="data row14 col2" >7.30</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b1e7e_row15_col0" class="data row15 col0" >Timothy Van Patten</td>
#       <td id="T_b1e7e_row15_col1" class="data row15 col1" >8.54</td>
#       <td id="T_b1e7e_row15_col2" class="data row15 col2" >7.78</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b1e7e_row16_col0" class="data row16 col0" >Tim Kirkby</td>
#       <td id="T_b1e7e_row16_col1" class="data row16 col1" >8.52</td>
#       <td id="T_b1e7e_row16_col2" class="data row16 col2" >5.92</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b1e7e_row17_col0" class="data row17 col0" >Steve Shill</td>
#       <td id="T_b1e7e_row17_col1" class="data row17 col1" >8.50</td>
#       <td id="T_b1e7e_row17_col2" class="data row17 col2" >8.34</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b1e7e_row18_col0" class="data row18 col0" >David Mandel</td>
#       <td id="T_b1e7e_row18_col1" class="data row18 col1" >8.50</td>
#       <td id="T_b1e7e_row18_col2" class="data row18 col2" >8.26</td>
#     </tr>
#     <tr>
#       <th id="T_b1e7e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b1e7e_row19_col0" class="data row19 col0" >Christopher Misiano</td>
#       <td id="T_b1e7e_row19_col1" class="data row19 col1" >8.50</td>
#       <td id="T_b1e7e_row19_col2" class="data row19 col2" >8.18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Question 3**
#
#
# > Identify movies that have the largest gap between critical reception (IMDb rating) and commercial success (number of votes) over the last 10 years, grouped by genre.

# %%
recent_movies = (
    data_frames["title_basics"]
    .filter(
        (F.col("startYear") >= 2015) &
        (F.col("startYear") <= 2025) &
        (col("genres") != "\\N")
    )
    .select("tconst", "genres")
)

movie_ratings = data_frames["title_ratings"].select("tconst", "averageRating", "numVotes")

movies_with_ratings = (
    recent_movies
    .join(movie_ratings, "tconst")
    .filter(
        F.col("averageRating").isNotNull() &
        F.col("numVotes").isNotNull()
    )
)

movies_with_ratings = movies_with_ratings.withColumn(
    "rating_vote_gap",
    (F.col("averageRating") - F.log(F.col("numVotes")))
)

genre_gap = (
    movies_with_ratings.groupBy("genres")
    .agg(
        F.max("rating_vote_gap").alias("max_gap"),
        F.avg("averageRating").alias("avg_rating"),
        F.avg("numVotes").alias("avg_votes")
    )
    .orderBy("max_gap", ascending=False)
)

total_records = genre_gap.count()
print(f"Загальна кількість записів у відповіді: {total_records}")

genre_gap_pd = genre_gap.select("genres", "max_gap", "avg_rating", "avg_votes").limit(20).toPandas()
genre_gap_pd.style \
    .format({
        "max_gap": "{:.2f}",
        "avg_rating": "{:.2f}",
        "avg_votes": "{:.2f}"
    }) \
    .set_properties(**{'background-color': '#f9f9f9', 'color': 'black'})
# Out:
# Загальна кількість записів у відповіді: 1653
# <style type="text/css">
# #T_16edc_row0_col0, #T_16edc_row0_col1, #T_16edc_row0_col2, #T_16edc_row0_col3, #T_16edc_row1_col0, #T_16edc_row1_col1, #T_16edc_row1_col2, #T_16edc_row1_col3, #T_16edc_row2_col0, #T_16edc_row2_col1, #T_16edc_row2_col2, #T_16edc_row2_col3, #T_16edc_row3_col0, #T_16edc_row3_col1, #T_16edc_row3_col2, #T_16edc_row3_col3, #T_16edc_row4_col0, #T_16edc_row4_col1, #T_16edc_row4_col2, #T_16edc_row4_col3, #T_16edc_row5_col0, #T_16edc_row5_col1, #T_16edc_row5_col2, #T_16edc_row5_col3, #T_16edc_row6_col0, #T_16edc_row6_col1, #T_16edc_row6_col2, #T_16edc_row6_col3, #T_16edc_row7_col0, #T_16edc_row7_col1, #T_16edc_row7_col2, #T_16edc_row7_col3, #T_16edc_row8_col0, #T_16edc_row8_col1, #T_16edc_row8_col2, #T_16edc_row8_col3, #T_16edc_row9_col0, #T_16edc_row9_col1, #T_16edc_row9_col2, #T_16edc_row9_col3, #T_16edc_row10_col0, #T_16edc_row10_col1, #T_16edc_row10_col2, #T_16edc_row10_col3, #T_16edc_row11_col0, #T_16edc_row11_col1, #T_16edc_row11_col2, #T_16edc_row11_col3, #T_16edc_row12_col0, #T_16edc_row12_col1, #T_16edc_row12_col2, #T_16edc_row12_col3, #T_16edc_row13_col0, #T_16edc_row13_col1, #T_16edc_row13_col2, #T_16edc_row13_col3, #T_16edc_row14_col0, #T_16edc_row14_col1, #T_16edc_row14_col2, #T_16edc_row14_col3, #T_16edc_row15_col0, #T_16edc_row15_col1, #T_16edc_row15_col2, #T_16edc_row15_col3, #T_16edc_row16_col0, #T_16edc_row16_col1, #T_16edc_row16_col2, #T_16edc_row16_col3, #T_16edc_row17_col0, #T_16edc_row17_col1, #T_16edc_row17_col2, #T_16edc_row17_col3, #T_16edc_row18_col0, #T_16edc_row18_col1, #T_16edc_row18_col2, #T_16edc_row18_col3, #T_16edc_row19_col0, #T_16edc_row19_col1, #T_16edc_row19_col2, #T_16edc_row19_col3 {
#   background-color: #f9f9f9;
#   color: black;
# }
# </style>
# <table id="T_16edc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16edc_level0_col0" class="col_heading level0 col0" >genres</th>
#       <th id="T_16edc_level0_col1" class="col_heading level0 col1" >max_gap</th>
#       <th id="T_16edc_level0_col2" class="col_heading level0 col2" >avg_rating</th>
#       <th id="T_16edc_level0_col3" class="col_heading level0 col3" >avg_votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16edc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16edc_row0_col0" class="data row0 col0" >Musical,Short</td>
#       <td id="T_16edc_row0_col1" class="data row0 col1" >8.39</td>
#       <td id="T_16edc_row0_col2" class="data row0 col2" >7.59</td>
#       <td id="T_16edc_row0_col3" class="data row0 col3" >30.20</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16edc_row1_col0" class="data row1 col0" >Animation,Comedy</td>
#       <td id="T_16edc_row1_col1" class="data row1 col1" >8.39</td>
#       <td id="T_16edc_row1_col2" class="data row1 col2" >7.11</td>
#       <td id="T_16edc_row1_col3" class="data row1 col3" >293.33</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16edc_row2_col0" class="data row2 col0" >Action,Comedy</td>
#       <td id="T_16edc_row2_col1" class="data row2 col1" >8.39</td>
#       <td id="T_16edc_row2_col2" class="data row2 col2" >6.39</td>
#       <td id="T_16edc_row2_col3" class="data row2 col3" >1809.92</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16edc_row3_col0" class="data row3 col0" >Documentary</td>
#       <td id="T_16edc_row3_col1" class="data row3 col1" >8.39</td>
#       <td id="T_16edc_row3_col2" class="data row3 col2" >7.31</td>
#       <td id="T_16edc_row3_col3" class="data row3 col3" >105.07</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16edc_row4_col0" class="data row4 col0" >Comedy,Game-Show</td>
#       <td id="T_16edc_row4_col1" class="data row4 col1" >8.39</td>
#       <td id="T_16edc_row4_col2" class="data row4 col2" >7.29</td>
#       <td id="T_16edc_row4_col3" class="data row4 col3" >57.74</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_16edc_row5_col0" class="data row5 col0" >News,Talk-Show</td>
#       <td id="T_16edc_row5_col1" class="data row5 col1" >8.39</td>
#       <td id="T_16edc_row5_col2" class="data row5 col2" >6.96</td>
#       <td id="T_16edc_row5_col3" class="data row5 col3" >36.42</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_16edc_row6_col0" class="data row6 col0" >Drama</td>
#       <td id="T_16edc_row6_col1" class="data row6 col1" >8.39</td>
#       <td id="T_16edc_row6_col2" class="data row6 col2" >7.05</td>
#       <td id="T_16edc_row6_col3" class="data row6 col3" >429.87</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_16edc_row7_col0" class="data row7 col0" >Action,Animation,Comedy</td>
#       <td id="T_16edc_row7_col1" class="data row7 col1" >8.39</td>
#       <td id="T_16edc_row7_col2" class="data row7 col2" >7.30</td>
#       <td id="T_16edc_row7_col3" class="data row7 col3" >351.96</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_16edc_row8_col0" class="data row8 col0" >Documentary,History</td>
#       <td id="T_16edc_row8_col1" class="data row8 col1" >8.39</td>
#       <td id="T_16edc_row8_col2" class="data row8 col2" >7.36</td>
#       <td id="T_16edc_row8_col3" class="data row8 col3" >152.38</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_16edc_row9_col0" class="data row9 col0" >Reality-TV</td>
#       <td id="T_16edc_row9_col1" class="data row9 col1" >8.39</td>
#       <td id="T_16edc_row9_col2" class="data row9 col2" >7.11</td>
#       <td id="T_16edc_row9_col3" class="data row9 col3" >39.94</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_16edc_row10_col0" class="data row10 col0" >Drama,Romance</td>
#       <td id="T_16edc_row10_col1" class="data row10 col1" >8.39</td>
#       <td id="T_16edc_row10_col2" class="data row10 col2" >7.51</td>
#       <td id="T_16edc_row10_col3" class="data row10 col3" >740.94</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_16edc_row11_col0" class="data row11 col0" >Family</td>
#       <td id="T_16edc_row11_col1" class="data row11 col1" >8.39</td>
#       <td id="T_16edc_row11_col2" class="data row11 col2" >7.00</td>
#       <td id="T_16edc_row11_col3" class="data row11 col3" >92.37</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_16edc_row12_col0" class="data row12 col0" >Crime,Drama</td>
#       <td id="T_16edc_row12_col1" class="data row12 col1" >8.39</td>
#       <td id="T_16edc_row12_col2" class="data row12 col2" >7.23</td>
#       <td id="T_16edc_row12_col3" class="data row12 col3" >938.64</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_16edc_row13_col0" class="data row13 col0" >Adventure,Animation,Comedy</td>
#       <td id="T_16edc_row13_col1" class="data row13 col1" >8.39</td>
#       <td id="T_16edc_row13_col2" class="data row13 col2" >7.21</td>
#       <td id="T_16edc_row13_col3" class="data row13 col3" >1062.54</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_16edc_row14_col0" class="data row14 col0" >Comedy,Drama,Horror</td>
#       <td id="T_16edc_row14_col1" class="data row14 col1" >8.39</td>
#       <td id="T_16edc_row14_col2" class="data row14 col2" >6.95</td>
#       <td id="T_16edc_row14_col3" class="data row14 col3" >1165.45</td>
#     </tr>
#     <tr>
#       <th id="T_16edc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_16edc_row15_col0" class="data row15 col0" >Adve

# %% [markdown]
# # **Question 4**
#
#
# > Compare average rating of series for each actor/actress with the average rating of films

# %%
movies = data_frames["title_basics"].filter(F.col("titleType") == "movie")
series = data_frames["title_basics"].filter(F.col("titleType") == "tvSeries")

movie_ratings = (
    data_frames["title_ratings"].join(movies, "tconst", "inner")
    .select("tconst", "averageRating", "titleType")
)

series_ratings = (
    data_frames["title_ratings"].join(series, "tconst", "inner")
    .select("tconst", "averageRating", "titleType")
)

# Join with title_principals to get actor/actress 'nconst' and their participation in movies/series
movies_with_actors = (
    movie_ratings.join(data_frames["title_principals"], "tconst")
    .join(data_frames["name_basics"], "nconst")
    .select("nconst", "primaryName", "averageRating", "titleType", "tconst")
)

series_with_actors = (
    series_ratings.join(data_frames["title_principals"], "tconst")
    .join(data_frames["name_basics"], "nconst")
    .select("nconst", "primaryName", "averageRating", "titleType", "tconst")
)

# Group by actor/actress and calculate average ratings for movies and series
# For movies
movies_avg_ratings = (
    movies_with_actors.groupBy("primaryName")
    .agg(
        F.avg("averageRating").alias("avg_movie_rating"),
        F.count("tconst").alias("movie_count")
    )
)
# For series
series_avg_ratings = (
    series_with_actors.groupBy("primaryName")
    .agg(
        F.avg("averageRating").alias("avg_series_rating"),
        F.count("tconst").alias("series_count")
    )
)
# Filter for actors/actresses who have at least 5 titles in both movies and series
actors_with_both = (
    movies_avg_ratings.join(series_avg_ratings, "primaryName")
    .filter(
        (F.col("movie_count") >= 5) &
        (F.col("series_count") >= 5) &
        (F.col("primaryName") == "\\N")
    )
)

total_records = actors_with_both.count()
print(f"Загальна кількість записів у відповіді: {total_records}")

actors_comparison_pd = actors_with_both.select("primaryName", "avg_movie_rating", "avg_series_rating").limit(20).toPandas()
actors_comparison_pd.style \
    .format({
        "avg_movie_rating": "{:.2f}",
        "avg_series_rating": "{:.2f}",
    }) \
    .set_properties(**{'background-color': '#f9f9f9', 'color': 'black'})
# Out:
# Загальна кількість записів у відповіді: 26003
# <style type="text/css">
# #T_8717d_row0_col0, #T_8717d_row0_col1, #T_8717d_row0_col2, #T_8717d_row1_col0, #T_8717d_row1_col1, #T_8717d_row1_col2, #T_8717d_row2_col0, #T_8717d_row2_col1, #T_8717d_row2_col2, #T_8717d_row3_col0, #T_8717d_row3_col1, #T_8717d_row3_col2, #T_8717d_row4_col0, #T_8717d_row4_col1, #T_8717d_row4_col2, #T_8717d_row5_col0, #T_8717d_row5_col1, #T_8717d_row5_col2, #T_8717d_row6_col0, #T_8717d_row6_col1, #T_8717d_row6_col2, #T_8717d_row7_col0, #T_8717d_row7_col1, #T_8717d_row7_col2, #T_8717d_row8_col0, #T_8717d_row8_col1, #T_8717d_row8_col2, #T_8717d_row9_col0, #T_8717d_row9_col1, #T_8717d_row9_col2, #T_8717d_row10_col0, #T_8717d_row10_col1, #T_8717d_row10_col2, #T_8717d_row11_col0, #T_8717d_row11_col1, #T_8717d_row11_col2, #T_8717d_row12_col0, #T_8717d_row12_col1, #T_8717d_row12_col2, #T_8717d_row13_col0, #T_8717d_row13_col1, #T_8717d_row13_col2, #T_8717d_row14_col0, #T_8717d_row14_col1, #T_8717d_row14_col2, #T_8717d_row15_col0, #T_8717d_row15_col1, #T_8717d_row15_col2, #T_8717d_row16_col0, #T_8717d_row16_col1, #T_8717d_row16_col2, #T_8717d_row17_col0, #T_8717d_row17_col1, #T_8717d_row17_col2, #T_8717d_row18_col0, #T_8717d_row18_col1, #T_8717d_row18_col2, #T_8717d_row19_col0, #T_8717d_row19_col1, #T_8717d_row19_col2 {
#   background-color: #f9f9f9;
#   color: black;
# }
# </style>
# <table id="T_8717d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8717d_level0_col0" class="col_heading level0 col0" >primaryName</th>
#       <th id="T_8717d_level0_col1" class="col_heading level0 col1" >avg_movie_rating</th>
#       <th id="T_8717d_level0_col2" class="col_heading level0 col2" >avg_series_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8717d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8717d_row0_col0" class="data row0 col0" >'Weird Al' Yankovic</td>
#       <td id="T_8717d_row0_col1" class="data row0 col1" >6.33</td>
#       <td id="T_8717d_row0_col2" class="data row0 col2" >7.12</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8717d_row1_col0" class="data row1 col0" >50 Cent</td>
#       <td id="T_8717d_row1_col1" class="data row1 col1" >5.67</td>
#       <td id="T_8717d_row1_col2" class="data row1 col2" >6.18</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8717d_row2_col0" class="data row2 col0" >A.D. Miles</td>
#       <td id="T_8717d_row2_col1" class="data row2 col1" >6.54</td>
#       <td id="T_8717d_row2_col2" class="data row2 col2" >7.29</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8717d_row3_col0" class="data row3 col0" >A.J. Benza</td>
#       <td id="T_8717d_row3_col1" class="data row3 col1" >5.66</td>
#       <td id="T_8717d_row3_col2" class="data row3 col2" >6.86</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8717d_row4_col0" class="data row4 col0" >A.J. Henderson</td>
#       <td id="T_8717d_row4_col1" class="data row4 col1" >5.63</td>
#       <td id="T_8717d_row4_col2" class="data row4 col2" >7.22</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8717d_row5_col0" class="data row5 col0" >A.J. Johnson</td>
#       <td id="T_8717d_row5_col1" class="data row5 col1" >5.45</td>
#       <td id="T_8717d_row5_col2" class="data row5 col2" >7.03</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8717d_row6_col0" class="data row6 col0" >A.K. Hangal</td>
#       <td id="T_8717d_row6_col1" class="data row6 col1" >6.37</td>
#       <td id="T_8717d_row6_col2" class="data row6 col2" >7.48</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8717d_row7_col0" class="data row7 col0" >AJ Michalka</td>
#       <td id="T_8717d_row7_col1" class="data row7 col1" >5.65</td>
#       <td id="T_8717d_row7_col2" class="data row7 col2" >7.19</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8717d_row8_col0" class="data row8 col0" >Aadar Malik</td>
#       <td id="T_8717d_row8_col1" class="data row8 col1" >7.02</td>
#       <td id="T_8717d_row8_col2" class="data row8 col2" >5.12</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8717d_row9_col0" class="data row9 col0" >Aadukalam Naren</td>
#       <td id="T_8717d_row9_col1" class="data row9 col1" >5.82</td>
#       <td id="T_8717d_row9_col2" class="data row9 col2" >7.10</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8717d_row10_col0" class="data row10 col0" >Aamir Bashir</td>
#       <td id="T_8717d_row10_col1" class="data row10 col1" >6.60</td>
#       <td id="T_8717d_row10_col2" class="data row10 col2" >7.68</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8717d_row11_col0" class="data row11 col0" >Aarohi Patel</td>
#       <td id="T_8717d_row11_col1" class="data row11 col1" >7.70</td>
#       <td id="T_8717d_row11_col2" class="data row11 col2" >7.92</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8717d_row12_col0" class="data row12 col0" >Aaron Brown</td>
#       <td id="T_8717d_row12_col1" class="data row12 col1" >6.25</td>
#       <td id="T_8717d_row12_col2" class="data row12 col2" >6.49</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8717d_row13_col0" class="data row13 col0" >Aaron Hill</td>
#       <td id="T_8717d_row13_col1" class="data row13 col1" >5.41</td>
#       <td id="T_8717d_row13_col2" class="data row13 col2" >7.81</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8717d_row14_col0" class="data row14 col0" >Aaron Jackson</td>
#       <td id="T_8717d_row14_col1" class="data row14 col1" >4.83</td>
#       <td id="T_8717d_row14_col2" class="data row14 col2" >7.04</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_8717d_row15_col0" class="data row15 col0" >Aaron Martin</td>
#       <td id="T_8717d_row15_col1" class="data row15 col1" >5.88</td>
#       <td id="T_8717d_row15_col2" class="data row15 col2" >6.86</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_8717d_row16_col0" class="data row16 col0" >Aaron May</td>
#       <td id="T_8717d_row16_col1" class="data row16 col1" >7.00</td>
#       <td id="T_8717d_row16_col2" class="data row16 col2" >6.00</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_8717d_row17_col0" class="data row17 col0" >Aaron Poole</td>
#       <td id="T_8717d_row17_col1" class="data row17 col1" >5.87</td>
#       <td id="T_8717d_row17_col2" class="data row17 col2" >7.08</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_8717d_row18_col0" class="data row18 col0" >Aaron Taylor-Johnson</td>
#       <td id="T_8717d_row18_col1" class="data row18 col1" >6.63</td>
#       <td id="T_8717d_row18_col2" class="data row18 col2" >6.79</td>
#     </tr>
#     <tr>
#       <th id="T_8717d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_8717d_row19_col0" class="data row19 col0" >Aarón Hernán</td>
#       <td id="T_8717d_row19_col1" class="data row19 col1" >6.26</td>
#       <td id="T_8717d_row19_col2" class="data row19 col2" >7.81</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **Question 5**
#
# > Determine how has the number of movies and TV series produced each year changed over time

# %%
title_basics = (
    data_frames["title_basics"]
    .filter(
        (F.col("startYear").isNotNull()) &
        (F.col("startYear") < 2025)
    )
)

title_basics_with_merged_types_df = title_basics.withColumn(
    "merged_title_type",
    F.when(F.col("titleType") == "tvMovie", "movie")
     .when(F.col("titleType") == "tvSeries", "tvMiniSeries")
     .otherwise(F.col("titleType"))
)

yearly_type_counts_df = (
    title_basics_with_merged_types_df
    .groupBy("startYear", "merged_title_type")
    .agg(F.count("*").alias("count"))
)

pivot_df = (
    yearly_type_counts_df
    .groupBy("startYear")
    .pivot("merged_title_type", ["movie", "tvMiniSeries"])
    .agg(F.first("count"))
)
pivot_df = pivot_df.dropna().orderBy("startYear")

renamed_df = (
    pivot_df
    .withColumnRenamed("movie", "movie_count")
    .withColumnRenamed("tvMiniSeries", "series_count")
)

window_spec = Window.orderBy("startYear")
lagged_df = (
    renamed_df
    .withColumn("prev_movie_count", F.lag("movie_count", 1, 0).over(window_spec))
    .withColumn("prev_series_count", F.lag("series_count", 1, 0).over(window_spec))
)

movies_year_df = (
    lagged_df
    .withColumn("movie_change", F.col("movie_count") - F.col("prev_movie_count"))
    .withColumn("series_change", F.col("series_count") - F.col("prev_series_count"))
    .orderBy(F.col("startYear").desc())
    .select("startYear", "movie_count", "series_count", "movie_change", "series_change")
)

movies_year_df_pd = movies_year_df.limit(20).toPandas()

total_records = movies_year_df.count()
print(f"Загальна кількість записів у відповіді: {total_records}")

movies_year_df_pd.style.set_properties(**{'background-color': '#f9f9f9', 'color': 'black'})
# Out:
# Загальна кількість записів у відповіді: 98
# <style type="text/css">
# #T_d7f62_row0_col0, #T_d7f62_row0_col1, #T_d7f62_row0_col2, #T_d7f62_row0_col3, #T_d7f62_row0_col4, #T_d7f62_row1_col0, #T_d7f62_row1_col1, #T_d7f62_row1_col2, #T_d7f62_row1_col3, #T_d7f62_row1_col4, #T_d7f62_row2_col0, #T_d7f62_row2_col1, #T_d7f62_row2_col2, #T_d7f62_row2_col3, #T_d7f62_row2_col4, #T_d7f62_row3_col0, #T_d7f62_row3_col1, #T_d7f62_row3_col2, #T_d7f62_row3_col3, #T_d7f62_row3_col4, #T_d7f62_row4_col0, #T_d7f62_row4_col1, #T_d7f62_row4_col2, #T_d7f62_row4_col3, #T_d7f62_row4_col4, #T_d7f62_row5_col0, #T_d7f62_row5_col1, #T_d7f62_row5_col2, #T_d7f62_row5_col3, #T_d7f62_row5_col4, #T_d7f62_row6_col0, #T_d7f62_row6_col1, #T_d7f62_row6_col2, #T_d7f62_row6_col3, #T_d7f62_row6_col4, #T_d7f62_row7_col0, #T_d7f62_row7_col1, #T_d7f62_row7_col2, #T_d7f62_row7_col3, #T_d7f62_row7_col4, #T_d7f62_row8_col0, #T_d7f62_row8_col1, #T_d7f62_row8_col2, #T_d7f62_row8_col3, #T_d7f62_row8_col4, #T_d7f62_row9_col0, #T_d7f62_row9_col1, #T_d7f62_row9_col2, #T_d7f62_row9_col3, #T_d7f62_row9_col4, #T_d7f62_row10_col0, #T_d7f62_row10_col1, #T_d7f62_row10_col2, #T_d7f62_row10_col3, #T_d7f62_row10_col4, #T_d7f62_row11_col0, #T_d7f62_row11_col1, #T_d7f62_row11_col2, #T_d7f62_row11_col3, #T_d7f62_row11_col4, #T_d7f62_row12_col0, #T_d7f62_row12_col1, #T_d7f62_row12_col2, #T_d7f62_row12_col3, #T_d7f62_row12_col4, #T_d7f62_row13_col0, #T_d7f62_row13_col1, #T_d7f62_row13_col2, #T_d7f62_row13_col3, #T_d7f62_row13_col4, #T_d7f62_row14_col0, #T_d7f62_row14_col1, #T_d7f62_row14_col2, #T_d7f62_row14_col3, #T_d7f62_row14_col4, #T_d7f62_row15_col0, #T_d7f62_row15_col1, #T_d7f62_row15_col2, #T_d7f62_row15_col3, #T_d7f62_row15_col4, #T_d7f62_row16_col0, #T_d7f62_row16_col1, #T_d7f62_row16_col2, #T_d7f62_row16_col3, #T_d7f62_row16_col4, #T_d7f62_row17_col0, #T_d7f62_row17_col1, #T_d7f62_row17_col2, #T_d7f62_row17_col3, #T_d7f62_row17_col4, #T_d7f62_row18_col0, #T_d7f62_row18_col1, #T_d7f62_row18_col2, #T_d7f62_row18_col3, #T_d7f62_row18_col4, #T_d7f62_row19_col0, #T_d7f62_row19_col1, #T_d7f62_row19_col2, #T_d7f62_row19_col3, #T_d7f62_row19_col4 {
#   background-color: #f9f9f9;
#   color: black;
# }
# </style>
# <table id="T_d7f62" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7f62_level0_col0" class="col_heading level0 col0" >startYear</th>
#       <th id="T_d7f62_level0_col1" class="col_heading level0 col1" >movie_count</th>
#       <th id="T_d7f62_level0_col2" class="col_heading level0 col2" >series_count</th>
#       <th id="T_d7f62_level0_col3" class="col_heading level0 col3" >movie_change</th>
#       <th id="T_d7f62_level0_col4" class="col_heading level0 col4" >series_change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7f62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7f62_row0_col0" class="data row0 col0" >2024</td>
#       <td id="T_d7f62_row0_col1" class="data row0 col1" >21447</td>
#       <td id="T_d7f62_row0_col2" class="data row0 col2" >11134</td>
#       <td id="T_d7f62_row0_col3" class="data row0 col3" >-1089</td>
#       <td id="T_d7f62_row0_col4" class="data row0 col4" >-1381</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7f62_row1_col0" class="data row1 col0" >2023</td>
#       <td id="T_d7f62_row1_col1" class="data row1 col1" >22536</td>
#       <td id="T_d7f62_row1_col2" class="data row1 col2" >12515</td>
#       <td id="T_d7f62_row1_col3" class="data row1 col3" >-520</td>
#       <td id="T_d7f62_row1_col4" class="data row1 col4" >-1686</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d7f62_row2_col0" class="data row2 col0" >2022</td>
#       <td id="T_d7f62_row2_col1" class="data row2 col1" >23056</td>
#       <td id="T_d7f62_row2_col2" class="data row2 col2" >14201</td>
#       <td id="T_d7f62_row2_col3" class="data row2 col3" >1324</td>
#       <td id="T_d7f62_row2_col4" class="data row2 col4" >-1841</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d7f62_row3_col0" class="data row3 col0" >2021</td>
#       <td id="T_d7f62_row3_col1" class="data row3 col1" >21732</td>
#       <td id="T_d7f62_row3_col2" class="data row3 col2" >16042</td>
#       <td id="T_d7f62_row3_col3" class="data row3 col3" >2445</td>
#       <td id="T_d7f62_row3_col4" class="data row3 col4" >-598</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d7f62_row4_col0" class="data row4 col0" >2020</td>
#       <td id="T_d7f62_row4_col1" class="data row4 col1" >19287</td>
#       <td id="T_d7f62_row4_col2" class="data row4 col2" >16640</td>
#       <td id="T_d7f62_row4_col3" class="data row4 col3" >-3357</td>
#       <td id="T_d7f62_row4_col4" class="data row4 col4" >1612</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d7f62_row5_col0" class="data row5 col0" >2019</td>
#       <td id="T_d7f62_row5_col1" class="data row5 col1" >22644</td>
#       <td id="T_d7f62_row5_col2" class="data row5 col2" >15028</td>
#       <td id="T_d7f62_row5_col3" class="data row5 col3" >-210</td>
#       <td id="T_d7f62_row5_col4" class="data row5 col4" >-235</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d7f62_row6_col0" class="data row6 col0" >2018</td>
#       <td id="T_d7f62_row6_col1" class="data row6 col1" >22854</td>
#       <td id="T_d7f62_row6_col2" class="data row6 col2" >15263</td>
#       <td id="T_d7f62_row6_col3" class="data row6 col3" >39</td>
#       <td id="T_d7f62_row6_col4" class="data row6 col4" >163</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d7f62_row7_col0" class="data row7 col0" >2017</td>
#       <td id="T_d7f62_row7_col1" class="data row7 col1" >22815</td>
#       <td id="T_d7f62_row7_col2" class="data row7 col2" >15100</td>
#       <td id="T_d7f62_row7_col3" class="data row7 col3" >228</td>
#       <td id="T_d7f62_row7_col4" class="data row7 col4" >759</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d7f62_row8_col0" class="data row8 col0" >2016</td>
#       <td id="T_d7f62_row8_col1" class="data row8 col1" >22587</td>
#       <td id="T_d7f62_row8_col2" class="data row8 col2" >14341</td>
#       <td id="T_d7f62_row8_col3" class="data row8 col3" >1352</td>
#       <td id="T_d7f62_row8_col4" class="data row8 col4" >615</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d7f62_row9_col0" class="data row9 col0" >2015</td>
#       <td id="T_d7f62_row9_col1" class="data row9 col1" >21235</td>
#       <td id="T_d7f62_row9_col2" class="data row9 col2" >13726</td>
#       <td id="T_d7f62_row9_col3" class="data row9 col3" >931</td>
#       <td id="T_d7f62_row9_col4" class="data row9 col4" >1291</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d7f62_row10_col0" class="data row10 col0" >2014</td>
#       <td id="T_d7f62_row10_col1" class="data row10 col1" >20304</td>
#       <td id="T_d7f62_row10_col2" class="data row10 col2" >12435</td>
#       <td id="T_d7f62_row10_col3" class="data row10 col3" >1260</td>
#       <td id="T_d7f62_row10_col4" class="data row10 col4" >766</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d7f62_row11_col0" class="data row11 col0" >2013</td>
#       <td id="T_d7f62_row11_col1" class="data row11 col1" >19044</td>
#       <td id="T_d7f62_row11_col2" class="data row11 col2" >11669</td>
#       <td id="T_d7f62_row11_col3" class="data row11 col3" >520</td>
#       <td id="T_d7f62_row11_col4" class="data row11 col4" >826</td>
#     </tr>
#     <tr>
#       <th id="T_d7f62_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d7f62_row12_c

# %% [markdown]
# # **Question 6**
#
#
# > Find directors who have at least 10 films, and at least one film has a rating at least 2 points higher than the average rating of all their other works.

# %%
# Filter directors with at least 10 films
director_films = (
    data_frames["title_crew"]
    .withColumn("director", F.explode(F.split(col("directors"), ",")))
    .join(data_frames["title_ratings"], "tconst")
    .join(data_frames["title_basics"], "tconst")
    .filter(col("director").isNotNull())
)

director_activity = (
    director_films
    .groupBy("directors")
    .agg(
        F.count("tconst").alias("num_movies"),
        F.avg("averageRating").alias("career_avg_rating")
    )
    .filter(
        (F.col("num_movies") >= 10) &
        (col("directors") != "\\N")
    )
)

# Find the film with highest rating for each director and calculate the difference
director_films_with_ratings = director_films.join(director_activity, "directors")
director_films_with_ratings = director_films_with_ratings.withColumn(
    "rating_diff",
    F.col("averageRating") - F.col("career_avg_rating")
)

director_rating_diff = (
    director_films_with_ratings
    .groupBy("directors")
    .agg(
        F.max("averageRating").alias("max_rating"),
        F.avg("averageRating").alias("career_avg_rating"),
        F.count("tconst").alias("film_count")
    )
    .withColumn("rating_diff", F.col("max_rating") - F.col("career_avg_rating"))
    .filter(F.col("rating_diff") >= 2)
    .orderBy(col("rating_diff").desc())
)

# Join with directors' names
directors_with_names = data_frames["name_basics"].select("nconst", "primaryName")

director_films_with_ratings = (
    director_rating_diff
    .join(directors_with_names, director_films_with_ratings["directors"] == directors_with_names["nconst"], "left")
    .select(
        directors_with_names["primaryName"].alias("director_name"),
        "rating_diff",
        "career_avg_rating",
        "max_rating"
    )
)
director_rating_diff_pd = director_films_with_ratings.limit(20).toPandas()

total_records = director_films_with_ratings.count()
print(f"Загальна кількість записів у відповіді: {total_records}")

director_rating_diff_pd.style \
    .format({
        "rating_diff": "{:.2f}",
        "career_avg_rating": "{:.2f}",
        "max_rating": "{:.2f}"
    }) \
    .set_properties(**{'background-color': '#f9f9f9', 'color': 'black'})
# Out:
# Загальна кількість записів у відповіді: 3998
# <style type="text/css">
# #T_c9700_row0_col0, #T_c9700_row0_col1, #T_c9700_row0_col2, #T_c9700_row0_col3, #T_c9700_row1_col0, #T_c9700_row1_col1, #T_c9700_row1_col2, #T_c9700_row1_col3, #T_c9700_row2_col0, #T_c9700_row2_col1, #T_c9700_row2_col2, #T_c9700_row2_col3, #T_c9700_row3_col0, #T_c9700_row3_col1, #T_c9700_row3_col2, #T_c9700_row3_col3, #T_c9700_row4_col0, #T_c9700_row4_col1, #T_c9700_row4_col2, #T_c9700_row4_col3, #T_c9700_row5_col0, #T_c9700_row5_col1, #T_c9700_row5_col2, #T_c9700_row5_col3, #T_c9700_row6_col0, #T_c9700_row6_col1, #T_c9700_row6_col2, #T_c9700_row6_col3, #T_c9700_row7_col0, #T_c9700_row7_col1, #T_c9700_row7_col2, #T_c9700_row7_col3, #T_c9700_row8_col0, #T_c9700_row8_col1, #T_c9700_row8_col2, #T_c9700_row8_col3, #T_c9700_row9_col0, #T_c9700_row9_col1, #T_c9700_row9_col2, #T_c9700_row9_col3, #T_c9700_row10_col0, #T_c9700_row10_col1, #T_c9700_row10_col2, #T_c9700_row10_col3, #T_c9700_row11_col0, #T_c9700_row11_col1, #T_c9700_row11_col2, #T_c9700_row11_col3, #T_c9700_row12_col0, #T_c9700_row12_col1, #T_c9700_row12_col2, #T_c9700_row12_col3, #T_c9700_row13_col0, #T_c9700_row13_col1, #T_c9700_row13_col2, #T_c9700_row13_col3, #T_c9700_row14_col0, #T_c9700_row14_col1, #T_c9700_row14_col2, #T_c9700_row14_col3, #T_c9700_row15_col0, #T_c9700_row15_col1, #T_c9700_row15_col2, #T_c9700_row15_col3, #T_c9700_row16_col0, #T_c9700_row16_col1, #T_c9700_row16_col2, #T_c9700_row16_col3, #T_c9700_row17_col0, #T_c9700_row17_col1, #T_c9700_row17_col2, #T_c9700_row17_col3, #T_c9700_row18_col0, #T_c9700_row18_col1, #T_c9700_row18_col2, #T_c9700_row18_col3, #T_c9700_row19_col0, #T_c9700_row19_col1, #T_c9700_row19_col2, #T_c9700_row19_col3 {
#   background-color: #f9f9f9;
#   color: black;
# }
# </style>
# <table id="T_c9700" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9700_level0_col0" class="col_heading level0 col0" >director_name</th>
#       <th id="T_c9700_level0_col1" class="col_heading level0 col1" >rating_diff</th>
#       <th id="T_c9700_level0_col2" class="col_heading level0 col2" >career_avg_rating</th>
#       <th id="T_c9700_level0_col3" class="col_heading level0 col3" >max_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9700_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9700_row0_col0" class="data row0 col0" >Roger Corman</td>
#       <td id="T_c9700_row0_col1" class="data row0 col1" >2.12</td>
#       <td id="T_c9700_row0_col2" class="data row0 col2" >5.38</td>
#       <td id="T_c9700_row0_col3" class="data row0 col3" >7.50</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9700_row1_col0" class="data row1 col0" >Danny DeVito</td>
#       <td id="T_c9700_row1_col1" class="data row1 col1" >2.12</td>
#       <td id="T_c9700_row1_col2" class="data row1 col2" >6.78</td>
#       <td id="T_c9700_row1_col3" class="data row1 col3" >8.90</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c9700_row2_col0" class="data row2 col0" >Robert Duncan McNeill</td>
#       <td id="T_c9700_row2_col1" class="data row2 col1" >2.02</td>
#       <td id="T_c9700_row2_col2" class="data row2 col2" >7.78</td>
#       <td id="T_c9700_row2_col3" class="data row2 col3" >9.80</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c9700_row3_col0" class="data row3 col0" >Leonard Nimoy</td>
#       <td id="T_c9700_row3_col1" class="data row3 col1" >2.04</td>
#       <td id="T_c9700_row3_col2" class="data row3 col2" >6.06</td>
#       <td id="T_c9700_row3_col3" class="data row3 col3" >8.10</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c9700_row4_col0" class="data row4 col0" >Michael Bay</td>
#       <td id="T_c9700_row4_col1" class="data row4 col1" >2.65</td>
#       <td id="T_c9700_row4_col2" class="data row4 col2" >6.55</td>
#       <td id="T_c9700_row4_col3" class="data row4 col3" >9.20</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c9700_row5_col0" class="data row5 col0" >Kathryn Bigelow</td>
#       <td id="T_c9700_row5_col1" class="data row5 col1" >2.33</td>
#       <td id="T_c9700_row5_col2" class="data row5 col2" >6.87</td>
#       <td id="T_c9700_row5_col3" class="data row5 col3" >9.20</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c9700_row6_col0" class="data row6 col0" >John Frankenheimer</td>
#       <td id="T_c9700_row6_col1" class="data row6 col1" >2.44</td>
#       <td id="T_c9700_row6_col2" class="data row6 col2" >6.86</td>
#       <td id="T_c9700_row6_col3" class="data row6 col3" >9.30</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c9700_row7_col0" class="data row7 col0" >Sydney Pollack</td>
#       <td id="T_c9700_row7_col1" class="data row7 col1" >2.07</td>
#       <td id="T_c9700_row7_col2" class="data row7 col2" >7.23</td>
#       <td id="T_c9700_row7_col3" class="data row7 col3" >9.30</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c9700_row8_col0" class="data row8 col0" >Joel Schumacher</td>
#       <td id="T_c9700_row8_col1" class="data row8 col1" >2.16</td>
#       <td id="T_c9700_row8_col2" class="data row8 col2" >6.34</td>
#       <td id="T_c9700_row8_col3" class="data row8 col3" >8.50</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c9700_row9_col0" class="data row9 col0" >Corey Allen</td>
#       <td id="T_c9700_row9_col1" class="data row9 col1" >2.48</td>
#       <td id="T_c9700_row9_col2" class="data row9 col2" >7.12</td>
#       <td id="T_c9700_row9_col3" class="data row9 col3" >9.60</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c9700_row10_col0" class="data row10 col0" >Gabriel Axel</td>
#       <td id="T_c9700_row10_col1" class="data row10 col1" >2.17</td>
#       <td id="T_c9700_row10_col2" class="data row10 col2" >5.93</td>
#       <td id="T_c9700_row10_col3" class="data row10 col3" >8.10</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c9700_row11_col0" class="data row11 col0" >Roger Christian</td>
#       <td id="T_c9700_row11_col1" class="data row11 col1" >2.06</td>
#       <td id="T_c9700_row11_col2" class="data row11 col2" >4.74</td>
#       <td id="T_c9700_row11_col3" class="data row11 col3" >6.80</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c9700_row12_col0" class="data row12 col0" >David Jackson</td>
#       <td id="T_c9700_row12_col1" class="data row12 col1" >2.88</td>
#       <td id="T_c9700_row12_col2" class="data row12 col2" >7.02</td>
#       <td id="T_c9700_row12_col3" class="data row12 col3" >9.90</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c9700_row13_col0" class="data row13 col0" >Gianni Lepre</td>
#       <td id="T_c9700_row13_col1" class="data row13 col1" >2.21</td>
#       <td id="T_c9700_row13_col2" class="data row13 col2" >6.69</td>
#       <td id="T_c9700_row13_col3" class="data row13 col3" >8.90</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c9700_row14_col0" class="data row14 col0" >Jay Holben</td>
#       <td id="T_c9700_row14_col1" class="data row14 col1" >2.81</td>
#       <td id="T_c9700_row14_col2" class="data row14 col2" >6.19</td>
#       <td id="T_c9700_row14_col3" class="data row14 col3" >9.00</td>
#     </tr>
#     <tr>
#       <th id="T_c9700_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c9700_row15_col0" class="data row15 col0" >John Putch</td>
#       <t

# %% [markdown]
# # **Save data**

# %%
degraded_genres.write.option("header", "true").csv("data/results/degraded_genres.csv")
upgraded_genres.write.option("header", "true").csv("data/results/upgraded_genres.csv")
career_trajectory_with_names.write.option("header", "true").csv("data/results/diresctors_career_trajectory.csv")
genre_gap.write.option("header", "true").csv("data/results//genre_gap.csv")
actors_with_both.write.option("header", "true").csv("data/results/actors_with_series_and_movies.csv")
movies_year_df.write.option("header", "true").csv("data/results/series_and_movies_per_year.csv")
director_films_with_ratings.write.option("header", "true").csv("data/results/director_films_with_ratings.csv")
